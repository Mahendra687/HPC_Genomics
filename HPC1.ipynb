# %% [markdown]
# ### Connect to the Cluster via SSH Run the following command:
#
# mahendra@ms:~$ `ssh se24plsc006@10.59.121.172`
#
# se24plsc006@10.59.121.172's password: `LKxSX5j3`
#
# se24plsc006@dgxcluster:~$ `sinfo`
#
# se24plsc006@dgxcluster:~$ `srun -N 1 --ntasks-per-node=2 --mem=8000 --time=2:00:00 --partition=gpu_scholar --pty bash`
#
# se24plsc006@dgxa:~$ `module avail`
#
# se24plsc006@dgxa:~$ `mkdir dataset output`
#
# se24plsc006@dgxa:~$ `module load FastQCv0.12.1`
#
# ### Step 6: Download the SRA Toolkit (if not available as a module)
# se24plsc006@dgxa:~$ `wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/3.2.0/sratoolkit.3.2.0-ubuntu64.tar.gz`
#
# ### Step 7: Extract the downloaded SRA Toolkit archive
# se24plsc006@dgxa:~$ `tar -xvzf sratoolkit.3.2.0-ubuntu64.tar.gz`
#
# se24plsc006@dgxa:~$ ls
#
# se24plsc006@dgxa:~$ `mkdir sratoolkit`
#
# se24plsc006@dgxa:~$ `mv sratoolkit.3.2.0-ubuntu64 sratoolkit/`
#
# se24plsc006@dgxa:~$ ls
#
# se24plsc006@dgxa:~$ `cd sratoolkit/`
#
# se24plsc006@dgxa:~/sratoolkit$ ls
#
# se24plsc006@dgxa:~$ `cd sratoolkit/`
#
# se24plsc006@dgxa:~/sratoolkit$ ls
#
# se24plsc006@dgxa:~$ `cd ~/sratoolkit/sratoolkit.3.2.0-ubuntu64`
#
# se24plsc006@dgxa:~/sratoolkit/sratoolkit.3.2.0-ubuntu64$ `export PATH=$PWD/bin:$PATH`
#
# se24plsc006@dgxa:~/sratoolkit/sratoolkit.3.2.0-ubuntu64$ `which vdb-config`
#
# se24plsc006@dgxa:~/sratoolkit/sratoolkit.3.2.0-ubuntu64$ `echo 'export PATH=$HOME/sratoolkit/sratoolkit.3.2.0-ubuntu64/bin:$PATH' >> ~/.bashrc`
#
# se24plsc006@dgxa:~/sratoolkit/sratoolkit.3.2.0-ubuntu64$ `vdb-config`
#
# se24plsc006@dgxa:~$ `vdb-config --help`
#
# se24plsc006@dgxa:~$ `source ~/.bashrc`
#
# se24plsc006@dgxa:~$ `prefetch SRR32066794`
#
# se24plsc006@dgxa:~$ `which fastq-dump`
#
# se24plsc006@dgxa:~$ `fasterq-dump SRR32066794 --outdir dataset`
#
# se24plsc006@dgxa:~/dataset$ ls
#
# se24plsc006@dgxa:~/dataset$ `head SRR32066794_1.fastq`
#
# se24plsc006@dgxa:~/dataset$ `head SRR32066794_2.fastq`
#
# se24plsc006@dgxa:~/dataset$ cd
#
# se24plsc006@dgxa:~$ `fastqc dataset/SRR32066794_1.fastq dataset/SRR32066794_2.fastq -o output`
#
# se24plsc006@dgxa:~$ `cd output/`
#
# se24plsc006@dgxa:~/output$ ls
